# %% [markdown]
# ### SymSpell Demo
# This notebook demonstrates how to use the SymSpell package to perform automated spell correction. As such, this notebook is little more than an example of the library's main functionality, but demonstrates how, in order to attain useful spell correction results, one need use much additional postprocessing and filtering to reduce the number of false-positive corrections.

# %%
from symspellpy import SymSpell, Verbosity
from tqdm.notebook import tqdm
import pandas as pd
import json
import re

# %%
corrections_big = []

# %%
df = pd.read_csv('res/bbc.csv')

# %%
sym_spell = SymSpell(max_dictionary_edit_distance=2, prefix_length=7)
sym_spell.create_dictionary('res/tokens_english.txt')
# Out:
# True

# %%
l = []
for tpl in tqdm(list(df.itertuples())):
    new_comments = []
    corrections = []
    for comment in tpl.text.split():
        new_comment = []
        for word in comment.split():
            clean = re.sub(r'[.,"\'\-%?(]', '', word.lower())
            suggestions = sym_spell.lookup(word, Verbosity.CLOSEST, max_edit_distance=2, include_unknown=True)
            replacement = [suggestion._term for suggestion in suggestions][0]
            
            if replacement.lower() == clean or word.istitle() or clean.isnumeric() or len(replacement) <= 2:
                new_comment.append(word)
                
            elif replacement != word:
                new_comment.append(replacement)
                corrections.append(f'{word} ---> {replacement}')
                corrections_big.append({'original': word, 'replacement': replacement})
                print(f'{word} ---> {replacement}')
                
        new_comments.append(' '.join(new_comment))
        
    l.append({'record': tpl.Index, 'comments': json.dumps(new_comments), 'corrections': json.dumps(corrections)})
        
df = pd.DataFrame(l).set_index('record')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# top-up ---> popup
# 2004's ---> 20049
# India's ---> indians
# India's ---> indians
# operation, ---> operations
# 650m ---> 16509
# 500m ---> 50002
# offer. ---> offers
# $17.04 ---> 71704
# announcement. ---> announcements
# company's ---> company
# 1930s. ---> 193038
# we've ---> weave
# we've ---> weave
# [the ---> the
# million-2 ---> million
# country's ---> country
# Venezuela's ---> venezuelans
# nation," ---> national
# Venezuela's ---> venezuelans
# $320m ---> 23200
# 5bn ---> bin
# Russia's ---> russians
# renationalisation ---> nationalisation
# thing," ---> things
# 1990s ---> 19902
# result, ---> results
# Putin's ---> outings
# effect. ---> effects
# effect, ---> effects
# country's ---> country
# benefit. ---> benefits
# hirings ---> firings
# Iraq's ---> iraqis
# $325m ---> 33250
# $1.3666 ---> 1163666
# Bush's ---> pushes
# dollar. ---> dollars
# Georgia's ---> georgians
# 1990s ---> 19902
# country's ---> country
# company's ---> company
# broke. ---> broken
# company's ---> company
# company's ---> company
# 136m ---> 14364
# deal. ---> deals
# sued, ---> suede
# 3bn ---> bin
# company's ---> company
# carmaker ---> lawmaker
# question, ---> questions
# co-head ---> godhead
# company's ---> company
# co-head ---> godhead
# 1bn ---> bin
# update. ---> updated
# 1130p ---> 19130
# added: ---> added
# dollar, ---> dollars
# £198m ---> 81984
# £130m ---> 41309
# £234m ---> 32348
# £220m ---> 52205
# £160m ---> 91601
# £610m ---> 36108
# £105m ---> 91057
# announcement". ---> announcements
# deal. ---> deals
# deal, ---> deals
# comment. ---> comments
# said: ---> said
# 210bn ---> 21034
# 1990s ---> 19902
# 'ticking ---> sticking
# 1970s. ---> 19708
# doesn't ---> don't
# 1950s ---> 19503
# security), ---> security
# roadmap ---> roadway
# city's ---> cities
# option. ---> options
# Wang's ---> ranges
# motorcades ---> motorcade
# outriders ---> outrider
# two-day ---> today
# Russia's ---> russians
# bust, ---> busty
# Russia's ---> russians
# man, ---> many
# 'le ---> ale
# 684bn ---> 68465
# 331bn ---> 33154
# Kraft's ---> crafts
# Kraft's ---> crafts
# hectares) ---> hectares
# hectare) ---> hectares
# question. ---> questions
# 19th ---> with
# country's ---> country
# added: ---> added
# country's ---> country
# advance, ---> advanced
# economy's ---> economy
# York's ---> works
# company's ---> company
# Marsh's ---> marshes
# America's ---> americans
# 6bn ---> bin
# country's ---> country
# 5bn ---> bin
# 9bn ---> bin
# country's ---> country
# country's ---> country
# roadmap ---> roadway
# country's ---> country
# country's ---> country
# product," ---> products
# country's ---> country
# May's ---> days
# cut-rate ---> butyrate
# service. ---> services
# service, ---> services
# 1990s ---> 19902
# star, ---> start
# country's ---> country
# workforce: ---> workforce
# sutras ---> suras
# country's ---> country
# asks; ---> asks
# worker? ---> workers
# York's ---> works
# that's ---> hats
# hi-tech ---> biotech
# today's ---> today
# America's ---> americans
# country's ---> country
# company's ---> company
# hands-on ---> hanson
# company's ---> company
# America's ---> americans
# India's ---> indians
# India's ---> indians
# India's ---> indians
# country's ---> country
# Libya's ---> libyans
# country's ---> country
# Libya's ---> libyans
# Israel's ---> israelis
# week; ---> week
# 2001; ---> 20015
# insurance: ---> insurance
# take-up ---> makeup
# suffered: ---> suffered
# activity; ---> activity
# recover," ---> recovery
# unguessable ---> guessable
# seem. ---> seems
# happens: ---> happens
# 2001; ---> 20015
# 300p ---> 63006
# £800m ---> 38005
# Glazer's ---> blazers
# Glazer's ---> blazers
# Glazer's ---> blazers
# deal. ---> deals
# Glazer's ---> blazers
# McManus ---> oceanus
# Glazer's ---> blazers
# that's ---> hats
# that's ---> hats
# involve. ---> involved
# $142m ---> 61429
# EBay ---> may
# $92.9 ---> 19299
# $103.05 ---> 710305
# service. ---> services
# EBay ---> may
# "I'm ---> i'm
# EBay ---> may
# $1.48 ---> 51848
# $1.52 ---> 21752
# $1.62 ---> 41262
# Iran's ---> brands
# Iran's ---> brands
# company's ---> company
# deal. ---> deals
# deal. ---> deals
# hardline ---> hardliner
# 19th ---> with
# direction." ---> directions
# index's ---> indexes
# $500m ---> 25006
# $10.44 ---> 41044
# financings ---> financing
# uncertain," ---> uncertainty
# $984m ---> 49841
# Blair's ---> lairs
# Africa's ---> africans
# Iraq's ---> iraqis
# frontman ---> frontal
# doesn't ---> don't
# laggard. ---> laggards
# That's ---> hats
# simple: ---> simple
# option." ---> options
# Kok's ---> jokes
# noted: ---> noted
# suit." ---> suite
# they're ---> there
# That's ---> hats
# they're ---> there
# clear: ---> clear
# doesn't ---> don't
# doesn't ---> don't
# Kok's ---> jokes
# company's ---> company
# ex-boss ---> emboss
# ex-head ---> egghead
# company's ---> company
# dollar, ---> dollars
# $1.35 ---> 51335
# euro/dollar ---> eurodollar
# carmaker ---> lawmaker
# carmaker ---> lawmaker
# result, ---> results
# euros) ---> euros
# product. ---> products
# arm, ---> army
# $900m ---> 79009
# onwards. ---> inwards
# today's ---> today
# $950m ---> 19503
# wasn't ---> can't
# wasn't ---> can't
# right. ---> rights
# estimate" ---> estimated
# eurozone ---> eurobond
# 253m ---> 26536
# attraction, ---> attractions
# company's ---> company
# history; ---> history
# take-up ---> makeup
# 578m ---> 75786
# 1990s ---> 19902
# $120m ---> 31205
# country's ---> country
# broke. ---> broken
# sell-offs ---> selloff
# renationalise ---> nationalise
# renationalisation ---> nationalisation
# result, ---> results
# country's ---> country
# $800m ---> 38005
# Arabia's ---> arabians
# country's ---> country
# requirement, ---> requirements
# result, ---> results
# industry's ---> industry
# company's ---> company
# 20th ---> with
# 20th ---> with
# Fox's ---> boxes
# offer, ---> offers
# company's ---> company
# $17.65 ---> 17365
# hour, ---> hours
# hour, ---> hours
# knock-on ---> knockdown
# Bush's ---> pushes
# fuel) ---> fuel
# result, ---> results
# euros) ---> euros
# product. ---> products
# usual". ---> usually
# India's ---> indians
# feet) ---> feet
# director, ---> directory
# India's ---> indians
# Bush's ---> pushes
# We'll ---> we'll
# deal. ---> deals
# Russia's ---> russians
# Russia's ---> russians
# back-tax ---> backstay
# country's ---> country
# Aid's ---> kids
# consenus ---> consensus
# country's ---> country
# lender, ---> lenders
# said: ---> said
# arrangement. ---> arrangements
# Fiat's ---> hiatus
# Fiat's ---> hiatus
# option". ---> options
# 'le ---> ale
# 684bn ---> 68465
# 331bn ---> 33154
# India's ---> indians
# Jet's ---> sets
# India's ---> indians
# offer, ---> offers
# Jet's ---> sets
# Jet's ---> sets
# Iraq's ---> iraqis
# $500m ---> 25006
# question. ---> questions
# Iraq's ---> iraqis
# Iraq's ---> iraqis
# ministry's ---> ministry
# Iraq's ---> iraqis
# competitor, ---> competitors
# I've ---> have
# statement: ---> statement
# estimate" ---> estimated
# eurozone ---> eurobond
# result, ---> results
# and/or ---> landor
# Russia's ---> russians
# comment. ---> comments
# Russia's ---> russians
# that's ---> hats
# Russia's ---> russians
# Glazer's ---> blazers
# fide ---> fidel
# offer, ---> offers
# Glazer's ---> blazers
# Glazer's ---> blazers
# offer, ---> offers
# McManus ---> oceanus
# Glazer's ---> blazers
# £800m ---> 38005
# 300p ---> 63006
# 270.25p ---> 2706256
# 3.75p ---> 34753
# £190m ---> 91901
# £265m ---> 32656
# $150,000 ---> 150000
# carmaker ---> lawmaker
# carmaker ---> lawmaker
# di ---> did
# 2004's ---> 20049
# haute ---> saute
# haute ---> saute
# saying: ---> saying
# service. ---> services
# rule, ---> rules
# agency: ---> agency
# $120m ---> 31205
# Asia's ---> asians
# pre-sale ---> resale
# Hexal's ---> exalts
# $200m ---> 42005
# Israel's ---> israelis
# deal. ---> deals
# "laddish ---> kaddish
# London's ---> condones
# $40.15 ---> 44015
# crudes ---> crudest
# $55.67 ---> 55967
# Opec's ---> specs
# $30-35 ---> 13035
# India's ---> indians
# Jet's ---> sets
# India's ---> indians
# offer, ---> offers
# Jet's ---> sets
# Jet's ---> sets
# result, ---> results
# $800m ---> 38005
# deal. ---> deals
# didn't ---> don't
# capita, ---> capital
# regulator, ---> regulatory
# 4bn ---> bin
# eurozone ---> eurobond
# bloc, ---> block
# $55.67 ---> 55967
# warned: ---> warned
# export-led ---> exported
# Bush's ---> pushes
# We'll ---> we'll
# May's ---> days
# 1990s. ---> 199083
# company's ---> company
# country's ---> country
# nation". ---> national
# term," ---> terms
# fuel) ---> fuel
# carmaker ---> lawmaker
# question, ---> questions
# operation. ---> operations
# country's ---> country
# country's ---> country
# result, ---> results
# juddering ---> laddering
# T-shirts ---> shirts
# fee. ---> feel
# said: ---> said
# country's ---> country
# economy's ---> economy
# 1990s ---> 19902
# dollar. ---> dollars
# 2004's ---> 20049
# "I'm ---> i'm
# own; ---> own
# Fiat's ---> hiatus
# right, ---> rights
# option', ---> options
# Fiat's ---> hiatus
# deal. ---> deals
# Australia's ---> australians
# factor, ---> factors
# right. ---> rights
# country's ---> country
# offer, ---> offers
# economy's ---> economy
# 110m ---> 18102
# 1990's ---> 199083
# Quake's ---> quakers
# emerge. ---> emerged
# India's ---> indians
# country's ---> country
# country's ---> country
# company's ---> company
# 27.2m ---> 27922
# 134.7m ---> 13478
# £800m ---> 38005
# Glazer's ---> blazers
# deal. ---> deals
# said: ---> said
# Glazer's ---> blazers
# proposals) ---> proposals
# £200m ---> 42005
# isn't ---> can't
# club; ---> club
# Glazer's ---> blazers
# Glazer's ---> blazers
# 300p ---> 63006
# 300p ---> 63006
# McManus ---> oceanus
# McManus ---> oceanus
# Glazer's ---> blazers
# deliver. ---> delivery
# term. ---> terms
# dollar, ---> dollars
# rand. ---> randy
# Iran's ---> brands
# 21st ---> list
# country's ---> country
# Iraq's ---> iraqis
# country's ---> country
# Iran's ---> brands
# Iran's ---> brands
# country's ---> country
# £800m ---> 38005
# deal. ---> deals
# deal. ---> deals
# said: ---> said
# Glazer's ---> blazers
# proposals) ---> proposals
# £200m ---> 42005
# isn't ---> can't
# club; ---> club
# Glazer's ---> blazers
# Glazer's ---> blazers
# 300p ---> 63006
# 300p ---> 63006
# McManus ---> oceanus
# McManus ---> oceanus
# Glazer's ---> blazers
# idea. ---> ideas
# India's ---> indians
# co-sign ---> consign
# Asia's ---> asians
# India's ---> indians
# take-up ---> makeup
# 578m ---> 75786
# 1990s ---> 19902
# country's ---> country
# own; ---> own
# Fiat's ---> hiatus
# right, ---> rights
# option', ---> options
# Fiat's ---> hiatus
# country's ---> country
# dollar. ---> dollars
# we've ---> weave
# America's ---> americans
# euros) ---> euros
# result, ---> results
# hour. ---> hours
# 548p. ---> 54882
# (assets) ---> assets
# company's ---> company
# said: ---> said
# term." ---> terms
# director, ---> directory
# 19th ---> with
# dollar. ---> dollars
# eurozone ---> eurobond
# £415m ---> 14159
# £425m ---> 94256
# Next's ---> texts
# that) ---> that
# wasn't ---> can't
# Next's ---> texts
# result," ---> results
# £420m ---> 14204
# Next's ---> texts
# renationalise ---> nationalise
# owner, ---> owners
# shareholder. ---> shareholders
# comment. ---> comments
# fines. ---> finest
# arm. ---> army
# country's ---> country
# man, ---> many
# deal, ---> deals
# too." ---> tools
# haute ---> saute
# haute ---> saute
# director, ---> directory
# job. ---> jobs
# country's ---> country
# Israel's ---> israelis
# Israel's ---> israelis
# carmaker ---> lawmaker
# carmaker ---> lawmaker
# 1.47m ---> 18472
# 200bn ---> 20052
# country's ---> country
# announcement. ---> announcements
# 20th ---> with
# 20th ---> with
# Fox's ---> boxes
# offer, ---> offers
# company's ---> company
# $17.65 ---> 17365
# $387m ---> 13873
# $111m ---> 21119
# 2003's ---> 20034
# $14.35 ---> 14535
# dam, ---> damn
# abided ---> aided
# country's ---> country
# part-time ---> partitive
# ever". ---> every
# trend," ---> trends
# £200m ---> 42005
# said: ---> said
# mad." ---> made
# Indonesia's ---> indonesians
# Indonesia's ---> indonesians
# carmaker ---> lawmaker
# carmaker ---> lawmaker
# "I'm ---> i'm
# merge. ---> merger
# lender, ---> lenders
# country's ---> country
# reinsurers ---> reinsured
# reinsurers ---> reinsured
# reinsurers ---> reinsured
# Re's ---> news
# analsyts ---> analysts
# Malaysia's ---> malaysians
# Asia's ---> asians
# dollar, ---> dollars
# 2003's ---> 20034
# knock-on ---> knockdown
# rebalancing ---> balancing
# dollar, ---> dollars
# Rover's ---> covers
# Rover's ---> covers
# carmaker ---> lawmaker
# $50,000 ---> 150000
# Indonesia's ---> indonesians
# requirement. ---> requirements
# economy's ---> economy
# prices] ---> prices
# term, ---> terms
# figures] ---> figures
# economy: ---> economy
# late." ---> latest
# eurozone ---> eurobond
# 789m ---> 78099
# 6bn ---> bin
# Korea's ---> koreans
# country's ---> country
# didn't ---> don't
# India's ---> indians
# Korea's ---> koreans
# back-end ---> backhand
# 1980s ---> 19805
# 1970s ---> 19708
# direction, ---> directions
# India's ---> indians
# comment. ---> comments
# Anil's ---> niles
# week; ---> week
# 2001; ---> 20015
# insurance: ---> insurance
# take-up ---> makeup
# suffered: ---> suffered
# activity; ---> activity
# recover," ---> recovery
# unguessable ---> guessable
# seem. ---> seems
# happens: ---> happens
# 2001; ---> 20015
# arm. ---> army
# £801m ---> 18014
# base. ---> based
# Africa's ---> africans
# country's ---> country
# da ---> day
# Lula's ---> gulags
# country's ---> country
# $900m ---> 79009
# $540m ---> 25400
# agency: ---> agency
# comment. ---> comments
# arm. ---> army
# demerge ---> emerge
# demerged ---> emerged
# demerger ---> emerged
# divisions: ---> divisions
# demerger ---> emerged
# £170m ---> 71707
# £194m ---> 21949
# 1940s ---> 19403
# Russia's ---> russians
# 259.7m ---> 25974
# 1960s, ---> 196038
# country's ---> country
# delisted ---> relisted
# didn't ---> don't
# 583p ---> 58931
# offer. ---> offers
# 533p ---> 55330
# added: ---> added
# 800m ---> 80908
# Fiat's ---> hiatus
# company's ---> company
# marque, ---> marquee
# 800m ---> 80908
# veteran, ---> veterans
# Africa's ---> africans
# transaction. ---> transactions
# merge. ---> merger
# lender, ---> lenders
# country's ---> country
# rule, ---> rules
# agency: ---> agency
# Blair's ---> lairs
# Africa's ---> africans
# Iraq's ---> iraqis
# frontman ---> frontal
# didn't ---> don't
# said: ---> said
# company's ---> company
# institution, ---> institutions
# litigations. ---> litigation
# India's ---> indians
# India's ---> indians
# operation, ---> operations
# Gartner's ---> partners
# Young's ---> lounges
# India's ---> indians
# surfwear ---> surfer
# dollar, ---> dollars
# country's ---> country
# back-tax ---> backstay
# 1bn ---> bin
# back-tax ---> backstay
# company's ---> company
# 2006/07 ---> 2406907
# matchday ---> hatchway
# option, ---> options
# product, ---> products
# fines. ---> finest
# two-day ---> today
# Russia's ---> russians
# Russia's ---> russians
# man, ---> many
# Russia's ---> russians
# we've ---> weave
# (meetings) ---> meetings
# Russia's ---> russians
# one-day ---> oneida
# hasn't ---> can't
# announcement. ---> announcements
# A380s ---> 13806
# A300s ---> 63006
# A300s ---> 63006
# company's ---> company
# 912km ---> 91215
# $900m ---> 79009
# $133m ---> 51335
# issue. ---> issues
# country's ---> country
# Libya's ---> libyans
# country's ---> country
# Libya's ---> libyans
# $120m ---> 31205
# country's ---> country
# broke. ---> broken
# report* ---> report
# income] ---> income
# receive, ---> received
# knew: ---> knew
# result, ---> results
# company's ---> company
# hugely: ---> hugely
# 1990s ---> 19902
# motivation: ---> motivation
# $53.09 ---> 853009
# $1.4850 ---> 314850
# added: ---> added
# Opec's ---> specs
# $2.80 ---> 52180
# $51.15 ---> 51415
# $55.67 ---> 55967
# 2004's ---> 20049
# $1.89 ---> 91789
# $48.62 ---> 14862
# Libya's ---> libyans
# result, ---> results
# India's ---> indians
# Jet's ---> sets
# India's ---> indians
# offer, ---> offers
# Jet's ---> sets
# Jet's ---> sets
# week; ---> week
# 2001; ---> 20015
# insurance: ---> insurance
# take-up ---> makeup
# suffered: ---> suffered
# activity; ---> activity
# recover," ---> recovery
# unguessable ---> guessable
# seem. ---> seems
# happens: ---> happens
# 2001; ---> 20015
# 2003's ---> 20034
# Bush's ---> pushes
# $1.15 ---> 91215
# $1.76 ---> 41976
# trend," ---> trends
# exception: ---> exception
# result, ---> results
# upside: ---> upside
# $1.30 ---> 81630
# Iran's ---> brands
# 21st ---> list
# country's ---> country
# Iraq's ---> iraqis
# country's ---> country
# Iran's ---> brands
# Iran's ---> brands
# India's ---> indians
# plane. ---> planet
# India's ---> indians
# operation. ---> operations
# India's ---> indians
# $413.50 ---> 641350
# ounce, ---> ounces
# 1970s ---> 19708
# 113.5m ---> 113956
# distribute. ---> distributed
# that's ---> hats
# concern. ---> concerns
# $630m ---> 16301
# $569m ---> 15691
# $838m ---> 68387
# Fiat's ---> hiatus
# Fiat's ---> hiatus
# deal, ---> deals
# 2bn ---> bin
# 1bn ---> bin
# 550m ---> 55706
# option" ---> options
# result, ---> results
# recapitalised ---> recapitalize
# India's ---> indians
# India's ---> indians
# company's ---> company
# Anil's ---> niles
# Anil's ---> niles
# company's ---> company
# India's ---> indians
# company's ---> company
# 745bn ---> 74599
# rupees). ---> rupees
# ever". ---> every
# trend," ---> trends
# £200m ---> 42005
# said: ---> said
# mad." ---> made
# £125m ---> 71257
# £106m ---> 71065
# £2.50 ---> 42850
# leg. ---> legs
# £160m ---> 91601
# ad ---> and
# $204m ---> 72046
# Algeria's ---> algerians
# miles) ---> miles
# Algeria's ---> algerians
# 1980s, ---> 198066
# thin, ---> think
# unprofitability ---> profitability
# merge. ---> merger
# lender, ---> lenders
# country's ---> country
# country's ---> country
# country's ---> country
# result, ---> results
# juddering ---> laddering
# 2bn ---> bin
# company's ---> company
# receive. ---> received
# lender, ---> lenders
# ariary. ---> friary
# ariary, ---> friary
# dollar. ---> dollars
# franc, ---> france
# franc, ---> france
# ariary ---> friary
# country's ---> country
# multi-billion ---> multimillion
# politicial ---> political
# country's ---> country
# Georgia's ---> georgians
# Georgia's ---> georgians
# Georgia's ---> georgians
# doesn't ---> don't
# Georgia's ---> georgians
# condition. ---> conditions
# £100m ---> 91004
# announcement, ---> announcements
# £280m ---> 12800
# they've ---> they'll
# £11,500 ---> 119500
# £15,690 ---> 1158690
# £8,000 ---> 987000
# the-car ---> theca
# 116i ---> 15165
# factory's ---> factory
# does; ---> does
# Russia's ---> russians
# we've ---> weave
# (meetings) ---> meetings
# Russia's ---> russians
# aide. ---> aided
# multi-billion ---> multimillion
# announcement. ---> announcements
# pound, ---> pounds
# haven't ---> haven
# dollar" ---> dollars
# condom, ---> condoms
# £173m ---> 21731
# fines, ---> finest
# accomodate ---> accommodate
# delisting. ---> relisting
# deregistration ---> reregistration
# capitalisations ---> capitalisation
# $700m ---> 17003
# multi-billion ---> multimillion
# reading: ---> reading
# offer. ---> offers
# announcement. ---> announcements
# operation. ---> operations
# $4.06 ---> 54706
# automotives ---> automotive
# labor ---> labour
# $220m ---> 52205
# $550m ---> 15503
# $100m ---> 91004
# $120m ---> 31205
# $200m ---> 42005
# Qatar's ---> tatars
# deal. ---> deals
# onwards. ---> inwards
# country's ---> country
# Liberia's ---> tiberias
# country's ---> country
# term, ---> terms
# onwards, ---> inwards
# brie. ---> brief
# company's ---> company
# rebrand ---> rembrandt
# product. ---> products
# anyone's ---> anyone
# feta." ---> fetal
# Russia's ---> russians
# Russia's ---> russians
# Russia's ---> russians
# doesn't ---> don't
# result." ---> results
# Russia's ---> russians
# £125m ---> 71257
# £106m ---> 71065
# £2.50 ---> 42850
# leg. ---> legs
# £160m ---> 91601
# $1.33 ---> 41933
# $42.30 ---> 54230
# $39.20 ---> 39920
# exporter. ---> exporters
# one-day ---> oneida
# pound, ---> pounds
# dollar. ---> dollars
# country's ---> country
# India's ---> indians
# India's ---> indians
# Poor's ---> doors
# country's ---> country
# India's ---> indians
# buoying ---> buying
# India's ---> indians
# director, ---> directory
# economy's ---> economy
# ad ---> and
# $204m ---> 72046
# $142m ---> 61429
# EBay ---> may
# $92.9 ---> 19299
# $103.05 ---> 710305
# service. ---> services
# EBay ---> may
# "I'm ---> i'm
# EBay ---> may
# $1.48 ---> 51848
# $1.52 ---> 21752
# $1.62 ---> 41262
# $12.33 ---> 21233
# piecemeal: ---> piecemeal
# $4.06 ---> 54706
# automotives ---> automotive
# labor ---> labour
# 325.5p ---> 32575
# 458.5p ---> 45895
# advance, ---> advanced
# economy's ---> economy
# $800m ---> 38005
# country's ---> country
# man. ---> many
# refuse. ---> refused
# Africa's ---> africans
# offer. ---> offers
# city's ---> cities
# option. ---> options
# Wang's ---> ranges
# motorcades ---> motorcade
# outriders ---> outrider
# $560m ---> 15603
# Opec's ---> specs
# $1.64 ---> 21564
# $1.32 ---> 91832
# supplier. ---> suppliers
# arm. ---> army
# £801m ---> 18014
# base. ---> based
# Africa's ---> africans
# country's ---> country
# country's ---> country
# lender, ---> lenders
# said: ---> said
# Africa's ---> africans
# $900m ---> 79009
# $540m ---> 25400
# agency: ---> agency
# comment. ---> comments
# arm. ---> army
# transaction. ---> transactions
# job. ---> jobs
# part-time ---> partitive
# worker, ---> workers
# Australia's ---> australians
# company's ---> company
# 1990s, ---> 199083
# "I'm ---> i'm
# lovin' ---> loving
# dollar, ---> dollars
# $1.35 ---> 51335
# euro/dollar ---> eurodollar
# ago; ---> ago
# deal. ---> deals
# didn't ---> don't
# doesn't ---> don't
# 873p, ---> 87340
# £328m ---> 43287
# 950p ---> 19503
# that's ---> hats
# co-head ---> godhead
# company's ---> company
# co-head ---> godhead
# 1bn ---> bin
# Chile's ---> whiles
# $950m ---> 19503
# Australia's ---> australians
# analyzing ---> analysing
# 1bn ---> bin
# country's ---> country
# Bush's ---> pushes
# Bush's ---> pushes
# one-day ---> oneida
# event," ---> events
# $1.26 ---> 41126
# $50.88 ---> 750988
# reserve. ---> reserved
# run-up ---> roundup
# Bush's ---> pushes
# issue. ---> issues
# Bush's ---> pushes
# America's ---> americans
# term. ---> terms
# India's ---> indians
# annoucement ---> announcement
# 705m ---> 47059
# 966m ---> 39666
# concern. ---> concerns
# agency's ---> agency
# part-time ---> partitive
# agency's ---> agency
# 3bn ---> bin
# 3bn ---> bin
# Qatar's ---> tatars
# deal. ---> deals
# onwards. ---> inwards
# back-tax ---> backstay
# 1bn ---> bin
# back-tax ---> backstay
# company's ---> company
# citizen. ---> citizens
# India's ---> indians
# 830bn ---> 83065
# country's ---> country
# India's ---> indians
# requirement. ---> requirements
# vis ---> visa
# vis ---> visa
# India's ---> indians
# India's ---> indians
# has: ---> has
# country's ---> country
# India's ---> indians
# base. ---> based
# announced: ---> announced
# Chile's ---> whiles
# $950m ---> 19503
# Australia's ---> australians
# analyzing ---> analysing
# £190m ---> 91901
# £265m ---> 32656
# Iraq's ---> iraqis
# Iraq's ---> iraqis
# ministry's ---> ministry
# re-enter ---> recenter
# Arabia's ---> arabians
# London's ---> condones
# Multiplex's ---> multiplexes
# resolve. ---> resolved
# India's ---> indians
# India's ---> indians
# $260m ---> 62606
# deal. ---> deals
# $50,000 ---> 150000
# Indonesia's ---> indonesians
# requirement. ---> requirements
# 100m ---> 13004
# Re's ---> news
# company's ---> company
# [companies] ---> companies
# $339m ---> 43390
# £308m ---> 23088
# deal. ---> deals
# 797p ---> 47974
# 2003's ---> 20034
# Bush's ---> pushes
# $1.15 ---> 91215
# $1.76 ---> 41976
# trend," ---> trends
# country's ---> country
# Liberia's ---> tiberias
# country's ---> country
# hectares) ---> hectares
# hectare) ---> hectares
# question. ---> questions
# 19th ---> with
# country's ---> country
# added: ---> added
# country's ---> country
# India's ---> indians
# feet) ---> feet
# director, ---> directory
# India's ---> indians
# 1980s, ---> 198066
# thin, ---> think
# unprofitability ---> profitability
# McManus ---> oceanus
# £800m ---> 38005
# £800m ---> 38005
# McManus ---> oceanus
# £800m ---> 38005
# Glazer's ---> blazers
# 300p ---> 63006
# McManus ---> oceanus
# 300p ---> 63006
# deal. ---> deals
# dollar, ---> dollars
# eurozone ---> eurobond
# $1.29 ---> 41129
# America's ---> americans
# direction. ---> directions
# Bush's ---> pushes
# business) ---> business
# that) ---> that
# isn't ---> can't
# hurting; ---> hurting
# country's ---> country
# year; ---> year
# doesn't ---> don't
# ever. ---> every
# offer. ---> offers
# that: ---> that
# result, ---> results
# 540bn ---> 54044
# carmaker ---> lawmaker
# 472bn ---> 47230
# rockwool ---> lockwood
# planks; ---> planks
# uplights, ---> plights
# washers) ---> washers
# dimmable ---> summable
# haven't ---> haven
# sterling's ---> sterling
# offer. ---> offers
# offer. ---> offers
# said: ---> said
# added: ---> added
# detail, ---> details
# Australia's ---> australians
# offer. ---> offers
# Australia's ---> australians
# country's ---> country
# country's ---> country
# Mexico's ---> lexicons
# $327 ---> 23627
# Mexico's ---> lexicons
# 'loses' ---> closest
# plane. ---> planet
# 3bn ---> bin
# 3bn ---> bin
# 2003's ---> 20034
# Bush's ---> pushes
# $1.15 ---> 91215
# $1.76 ---> 41976
# trend," ---> trends
# dollar, ---> dollars
# effect. ---> effects
# announcement, ---> announcements
# that's ---> hats
# plane, ---> planet
# industry's ---> industry
# planemaker ---> pacemaker
# plane, ---> planet
# plane. ---> planet
# offically ---> officially
# airplanes ---> warplanes
# company's ---> company
# $186m ---> 21866
# 143m ---> 14394
# euros) ---> euros
# doesn't ---> don't
# hour, ---> hours
# hour, ---> hours
# knock-on ---> knockdown
# Bush's ---> pushes
# result, ---> results
# euros) ---> euros
# product. ---> products
# carmaker ---> lawmaker
# carmaker ---> lawmaker
# deal' ---> deals
# offer. ---> offers
# city's ---> cities
# issue. ---> issues
# company's ---> company
# $500m ---> 25006
# cut-rate ---> butyrate
# service. ---> services
# service, ---> services
# 1990s ---> 19902
# star, ---> start
# country's ---> country
# they've ---> they'll
# company's ---> company
# £250 ---> 33250
# £500 ---> 25400
# £1,200 ---> 711200
# children's ---> children
# year). ---> year
# £100 ---> 91004
# parent) ---> parents
# parent. ---> parents
# children's ---> children
# £1,200 ---> 711200
# child's ---> childish
# £100 ---> 91004
# term, ---> terms
# tracker). ---> tracker
# 10.75p ---> 100759
# £138m ---> 91381
# £200m ---> 42005
# 200p. ---> 20052
# $320m ---> 23200
# 5bn ---> bin
# arm. ---> army
# £801m ---> 18014
# base. ---> based
# Africa's ---> africans
# 14th ---> with
# 1776's ---> 17766
# continued: ---> continued
# said: ---> said
# competitor, ---> competitors
# I've ---> have
# statement: ---> statement
# 3bn ---> bin
# 3bn ---> bin
# $600m ---> 36003
# deal, ---> deals
# company's ---> company
# 1990s. ---> 199083
# picture." ---> pictures
# bourses, ---> courses
# $500m ---> 25006
# deal. ---> deals
# India's ---> indians
# country's ---> country
# India's ---> indians
# India's ---> indians
# Russia's ---> russians
# India's ---> indians
# right, ---> rights
# citizen. ---> citizens
# India's ---> indians
# 830bn ---> 83065
# country's ---> country
# India's ---> indians
# requirement. ---> requirements
# vis ---> visa
# vis ---> visa
# India's ---> indians
# India's ---> indians
# has: ---> has
# country's ---> country
# India's ---> indians
# base. ---> based
# announced: ---> announced
# country's ---> country
# Georgia's ---> georgians
# Georgia's ---> georgians
# Georgia's ---> georgians
# doesn't ---> don't
# Georgia's ---> georgians
# condition. ---> conditions
# India's ---> indians
# India's ---> indians
# asset. ---> assets
# deal, ---> deals
# Kremlin's ---> gremlins
# renationalise ---> nationalise
# Putin's ---> outings
# carmaking ---> lawmaking
# America's ---> americans
# I'd ---> and
# Russia's ---> russians
# Russia's ---> russians
# Russia's ---> russians
# doesn't ---> don't
# result." ---> results
# Russia's ---> russians
# deal. ---> deals
# Australia's ---> australians
# factor, ---> factors
# right. ---> rights
# 1990s ---> 19902
# tag, ---> tags
# Lyle's ---> myles
# country's ---> country
# Tate's ---> rates
# Russia's ---> russians
# renationalisation ---> nationalisation
# thing," ---> things
# 1990s ---> 19902
# result, ---> results
# Putin's ---> outings
# retire. ---> retired
# contribution, ---> contributions
# 1990s. ---> 199083
# 2002/03 ---> 1200203
# provision," ---> provisions
# country's ---> country
# country's ---> country
# man, ---> many
# $800m ---> 38005
# partner," ---> partners
# Fed's ---> beds
# Fed's ---> beds
# Fed's ---> beds
# £250 ---> 33250
# £500 ---> 25400
# £1,200 ---> 711200
# children's ---> children
# year). ---> year
# £100 ---> 91004
# parent) ---> parents
# parent. ---> parents
# children's ---> children
# £1,200 ---> 711200
# child's ---> childish
# £100 ---> 91004
# term, ---> terms
# tracker). ---> tracker
# rule' ---> rules
# rule", ---> rules
# accelerate, ---> accelerated
# added: ---> added
# rebalance ---> rebalanced
# deteriorate, ---> deteriorated
# Fiat's ---> hiatus
# carmaking ---> lawmaking
# euros; ---> euros
# Fiat's ---> hiatus
# Fiat's ---> hiatus
# sportscar ---> sportscast
# 775m ---> 79759
# Russia's ---> russians
# renationalisation ---> nationalisation
# Russia's ---> russians
# Russia's ---> russians
# year-end ---> yearned
# Kremlin's ---> gremlins
# 1990s ---> 19902
# Russia's ---> russians
# fines. ---> finest
# renationalising ---> rationalising
# $5.15 ---> 35815
# hour, ---> hours
# Poor's ---> doors
# Russia's ---> russians
# Russia's ---> russians
# suit. ---> suite
# bet. ---> beta
# outweight ---> outweigh
# company's ---> company
# Kremlin's ---> gremlins
# $630m ---> 16301
# $569m ---> 15691
# $838m ---> 68387
# usual". ---> usually
# 1990s. ---> 199083
# picture." ---> pictures
# company's ---> company
# Australia's ---> australians
# costs]" ---> costs
# country's ---> country
# paycuts ---> payouts
# paycuts ---> payouts
# consultant. ---> consultants
# industry's ---> industry
# deal. ---> deals
# offer, ---> offers
# added: ---> added
# rebalance ---> rebalanced
# deteriorate, ---> deteriorated
# 'ticking ---> sticking
# 1970s. ---> 19708
# doesn't ---> don't
# 1950s ---> 19503
# security), ---> security
# £775, ---> 77759
# Bush's ---> pushes
# competitor, ---> competitors
# I've ---> have
# statement: ---> statement
# Peel's ---> feels
# said: ---> said
# said: ---> said
# Peel's ---> feels
# said: ---> said
# 1960s, ---> 196038
# said: ---> said
# you'd ---> would
# hear: ---> heart
# One's ---> news
# One's ---> news
# anti-gun ---> antigua
# anti-gun ---> antigua
# 'n' ---> and
# Knight's ---> nights
# glamorised, ---> glamorise
# movie. ---> movies
# 1970s ---> 19708
# 1940s ---> 19403
# 21st ---> list
# 70th ---> with
# impersonator. ---> impersonators
# 999th ---> 99909
# said: ---> said
# London's ---> condones
# 50th ---> with
# 28th ---> with
# star," ---> start
# said: ---> said
# he's ---> hers
# I'm ---> i'm
# added: ---> added
# King's ---> rings
# 70th ---> with
# 1980s ---> 19805
# re-released ---> rerelease
# said: ---> said
# scripts: ---> scripts
# auf ---> aug
# York's ---> works
# said: ---> said
# job," ---> jobs
# recommissioning ---> decommissioning
# movie, ---> movies
# she's ---> sheds
# issue." ---> issues
# Howl's ---> bowls
# Howl's ---> bowls
# Howl's ---> bowls
# children's ---> children
# witch's ---> witches
# idea, ---> ideas
# Singer's ---> fingers
# review: ---> review
# book. ---> books
# right. ---> rights
# frontman ---> frontal
# event. ---> events
# 21st ---> list
# aren't ---> parent
# idea." ---> ideas
# I'm ---> i'm
# I'm ---> i'm
# adding: ---> adding
# concluded: ---> concluded
# agreed: ---> agreed
# i.e. ---> item
# megastars ---> megastar
# multi-billion ---> multimillion
# goods! ---> goods
# fundamental: ---> fundamental
# no. ---> not
# deal". ---> deals
# they'd ---> they'll
# they'd ---> they'll
# they're ---> there
# musician. ---> musicians
# companies! ---> companies
# for! ---> for
# deal. ---> deals
# said: ---> said
# I'm ---> i'm
# £50,000 ---> 150000
# pre-show ---> peepshow
# Kenzie's ---> menzies
# Y'all ---> all
# "I'm ---> i'm
# said: ---> said
# didn't ---> don't
# 1990s ---> 19902
# children's ---> children
# said: ---> said
# I'm ---> i'm
# co-hosted ---> composted
# children's ---> children
# One's ---> news
# service, ---> services
# Stern's ---> terns
# service. ---> services
# event. ---> events
# (1998) ---> 19984
# Stern's ---> terns
# Leigh's ---> heights
# Man's ---> hands
# added: ---> added
# Man's ---> hands
# Man's ---> hands
# 20th ---> with
# 15th ---> with
# Cube's ---> tubes
# director: ---> directory
# you're ---> louvre
# I'm ---> i'm
# I'm ---> i'm
# I've ---> have
# $156m ---> 21569
# deal. ---> deals
# company's ---> company
# said: ---> said
# OutKast ---> outcast
# OutKast ---> outcast
# OutKast ---> outcast
# OutKast ---> outcast
# OutKast ---> outcast
# OutKast ---> outcast
# crowd: ---> crowd
# said: ---> said
# 11th ---> with
# children's ---> children
# element. ---> elements
# there's ---> theresa
# book, ---> books
# Aid's ---> kids
# Slade's ---> blades
# Wham's ---> thames
# OutKast ---> outcast
# 17th ---> with
# musician," ---> musicians
# director, ---> directory
# is', ---> i'm
# 'kill' ---> skills
# that's ---> hats
# who's ---> whose
# there's ---> theresa
# they're ---> there
# met." ---> metal
# director. ---> directory
# that's ---> hats
# director, ---> directory
# director: ---> directory
# I'm ---> i'm
# "I'm ---> i'm
# Leigh's ---> heights
# children's ---> children
# 1980s, ---> 198066
# "I'm ---> i'm
# I'll ---> i'll
# I've ---> have
# Leigh's ---> heights
# movie. ---> movies
# said: ---> said
# added: ---> added
# said: ---> said
# "I'm ---> i'm
# he's ---> hers
# Don't ---> won't
# you're ---> louvre
# I'm ---> i'm
# Who's ---> shows
# trivialises ---> trivializes
# man, ---> many
# idea, ---> ideas
# McGraw ---> craw
# event. ---> events
# star, ---> start
# 15th ---> with
# movie. ---> movies
# 1970s ---> 19708
# 1940s ---> 19403
# 21st ---> list
# component, ---> components
# Israel's ---> israelis
# million), ---> million
# her. ---> here
# 1980s ---> 19805
# story's ---> storeys
# book. ---> books
# Stern's ---> terns
# ad ---> and
# 1960s ---> 19609
# journeys!" ---> journeys
# $23,000 ---> 23000
# 98th ---> with
# service. ---> services
# said: ---> said
# service. ---> services
# £138m ---> 91381
# earner' ---> earners
# Stone's ---> tones
# 10th ---> with
# sold-out ---> foldout
# parent" ---> parents
# housemates: ---> housemates
# "I'm ---> i'm
# I'm ---> i'm
# £50,000 ---> 150000
# London's ---> condones
# £10,000 ---> 107000
# 19th ---> with
# Leroi's ---> heroics
# Leroi's ---> heroics
# memoir, ---> memoirs
# bestseller. ---> bestsellers
# said: ---> said
# 50th ---> with
# hit] ---> hit
# 5ive ---> live
# 1970s ---> 19708
# 60th ---> with
# I've ---> have
# didn't ---> don't
# I've ---> have
# wasn't ---> can't
# 1990s ---> 19902
# "I'm ---> i'm
# Mann's ---> cannes
# idea, ---> ideas
# Love's ---> covers
# remortgaged ---> remortgage
# £800m ---> 38005
# £300m ---> 63006
# £340m ---> 13401
# £220m ---> 52205
# Victoria's ---> victorians
# I'm ---> i'm
# they're ---> there
# 2004's ---> 20049
# public's ---> public
# haven't ---> haven
# 9/11 ---> 98011
# added: ---> added
# "I'm ---> i'm
# Rock's ---> cocks
# America's ---> americans
# Leigh's ---> heights
# fines' ---> finest
# legisation ---> legislation
# politcians ---> politicians
# million) ---> million
# $32,500 ---> 328500
# fines. ---> finest
# $150m ---> 31509
# Five's ---> gives
# event. ---> events
# (1998) ---> 19984
# said: ---> said
# 10th ---> with
# pre-orders ---> recorders
# pre-ordered ---> reordered
# ever, ---> every
# pre-ordered ---> reordered
# pre-order ---> recorder
# result". ---> results
# book, ---> books
# book, ---> books
# Drake's ---> brakes
# Leigh's ---> heights
# 1950s ---> 19503
# abortionist, ---> abortionists
# shoo-in ---> shooting
# Leigh's ---> heights
# Man's ---> hands
# partner, ---> partners
# star. ---> start
# $100m ---> 91004
# London's ---> condones
# book, ---> books
# 21st ---> list
# game. ---> games
# said: ---> said
# film-maker. ---> filmmakers
# We're ---> here
# abided ---> aided
# flutist, ---> flautist
# comment. ---> comments
# Singer's ---> fingers
# 2002's ---> 20029
# $6.25 ---> 46525
# $5.80 ---> 95180
# 9/11 ---> 98011
# audiences) ---> audiences
# said: ---> said
# $110 ---> 28110
# $1.25 ---> 21525
# daugher ---> laugher
# parent" ---> parents
# housemates: ---> housemates
# "I'm ---> i'm
# I'm ---> i'm
# £50,000 ---> 150000
# 'juror' ---> jurors
# person", ---> personal
# citizen. ---> citizens
# hadn't ---> can't
# $600 ---> 36003
# Hailey's ---> baileys
# 1980s, ---> 198066
# (1968) ---> 19689
# Hailey's ---> baileys
# airplane ---> warplane
# aiport ---> airport
# womanising ---> womanizing
# book. ---> books
# (1975) ---> 19755
# (1979) ---> 319795
# Hailey's ---> baileys
# Hailey's ---> baileys
# book, ---> books
# retire. ---> retired
# Hailey's ---> baileys
# earner' ---> earners
# Stone's ---> tones
# 10th ---> with
# sold-out ---> foldout
# One's ---> news
# chose. ---> chosen
# Cash's ---> ashes
# drive-in ---> driveline
# restaurant. ---> restaurants
# industry's ---> industry
# service. ---> services
# 1940s, ---> 19403
# 1987's ---> 19871
# 'n' ---> and
# 19th ---> with
# 999th ---> 99909
# 1000th ---> 100071
# That's ---> hats
# 1970s ---> 19708
# That's ---> hats
# 1950s ---> 19503
# 1947's ---> 19478
# 1950s ---> 19503
# pantos ---> santos
# man. ---> many
# said: ---> said
# I've ---> have
# book, ---> books
# book, ---> books
# trailblazed ---> trailblazer
# 1985's ---> 198594
# That's ---> hats
# 1970s ---> 19708
# That's ---> hats
# 1950s ---> 19503
# 1947's ---> 19478
# 1950s ---> 19503
# pantos ---> santos
# man. ---> many
# earner' ---> earners
# Stone's ---> tones
# 10th ---> with
# sold-out ---> foldout
# said: ---> said
# said: ---> said
# said: ---> said
# 2003's ---> 20034
# company's ---> company
# Jam's ---> games
# Jam's ---> games
# said: ---> said
# no-one ---> ozone
# Jam's ---> games
# said: ---> said
# added: ---> added
# Hall's ---> calls
# teacher. ---> teachers
# didn't ---> don't
# [older ---> older
# fans] ---> fans
# star, ---> start
# 1980s ---> 19805
# star, ---> start
# $110,00 ---> 110900
# two-day ---> today
# $30,000 ---> 300000
# $50,000 ---> 150000
# $2,115 ---> 27115
# children's ---> children
# said: ---> said
# I'm ---> i'm
# co-hosted ---> composted
# children's ---> children
# One's ---> news
# event. ---> events
# too." ---> tools
# event. ---> events
# £125 ---> 31205
# saying: ---> saying
# "I'm ---> i'm
# said: ---> said
# he's ---> hers
# doesn't ---> don't
# Dominica's ---> dominicans
# comment. ---> comments
# movie. ---> movies
# 1600s. ---> 16006
# $305m ---> 13059
# said: ---> said
# added: ---> added
# there's ---> theresa
# I've ---> have
# Don't ---> won't
# comic, ---> comics
# £1,950 ---> 718950
# We've ---> leave
# that's ---> hats
# said: ---> said
# didn't ---> don't
# 1960s ---> 19609
# £350 ---> 13350
# idea. ---> ideas
# you've ---> zouave
# "We'll ---> she'll
# 'n' ---> and
# 19th ---> with
# 999th ---> 99909
# 1000th ---> 100071
# country's ---> country
# said: ---> said
# Grace's ---> races
# 2004's ---> 20049
# 20th ---> with
# "dumbing ---> plumbing
# "victim" ---> victims
# today's ---> today
# Slim's ---> limbs
# 'right, ---> rights
# "I'm ---> i'm
# I've ---> have
# joie ---> josie
# vivre ---> livre
# that's ---> hats
# event, ---> events
# there's ---> theresa
# neighbour. ---> neighbours
# there's ---> theresa
# they're ---> there
# director, ---> directory
# we've ---> weave
# We've ---> leave
# usual." ---> usually
# Prater's ---> craters
# event, ---> events
# Leigh's ---> heights
# offputting ---> outputting
# I've ---> have
# I'm ---> i'm
# that's ---> hats
# 13th ---> with
# 12th ---> with
# result, ---> results
# didn't ---> don't
# wasn't ---> can't
# company's ---> company
# said: ---> said
# director, ---> directory
# we've ---> weave
# We've ---> leave
# usual." ---> usually
# Prater's ---> craters
# event, ---> events
# Leigh's ---> heights
# offputting ---> outputting
# I've ---> have
# I'm ---> i'm
# that's ---> hats
# said: ---> said
# Scholl's ---> chollas
# Scholl's ---> chollas
# Scholl's ---> chollas
# accolade. ---> accolades
# director, ---> directory
# 9/11 ---> 98011
# that's ---> hats
# London's ---> condones
# wholescale ---> wholesale
# million) ---> million
# Fox's ---> boxes
# comment. ---> comments
# Fox's ---> boxes
# 70th ---> with
# impersonator. ---> impersonators
# 999th ---> 99909
# said: ---> said
# movie. ---> movies
# concern. ---> concerns
# "unviable ---> enviable
# said: ---> said
# added: ---> added
# Bush's ---> pushes
# 60th ---> with
# I've ---> have
# didn't ---> don't
# I've ---> have
# wasn't ---> can't
# 1990s ---> 19902
# "I'm ---> i'm
# Cash's ---> ashes
# drive-in ---> driveline
# restaurant. ---> restaurants
# industry's ---> industry
# service. ---> services
# Lee's ---> needs
# said: ---> said
# that's ---> hats
# company's ---> company
# co-created ---> concreted
# said: ---> said
# Lee's ---> needs
# re-released ---> rerelease
# 20th ---> with
# event, ---> events
# 10th ---> with
# sold-out ---> foldout
# said: ---> said
# disappoint." ---> disappointed
# movie. ---> movies
# 1970s ---> 19708
# 1940s ---> 19403
# 21st ---> list
# 20th ---> with
# $291 ---> 18291
# (£152 ---> 76152
# million). ---> million
# picture, ---> pictures
# frontman ---> frontal
# clean-cut ---> clearcut
# didn't ---> don't
# He's ---> news
# 1960s, ---> 196038
# city's ---> cities
# reporters: ---> reporters
# haven't ---> haven
# said: ---> said
# I'm ---> i'm
# you're ---> louvre
# you're ---> louvre
# I'm ---> i'm
# I'm ---> i'm
# pinnies, ---> pennies
# audience: ---> audience
# I've ---> have
# "I'm ---> i'm
# I'd ---> and
# joking: ---> joking
# I'm ---> i'm
# I've ---> have
# I've ---> have
# star, ---> start
# 1980s ---> 19805
# star, ---> start
# 1980s, ---> 198066
# I've ---> have
# 1980s, ---> 198066
# right," ---> rights
# £870 ---> 38709
# £26,000 ---> 526000
# conterfeit ---> counterfeit
# said: ---> said
# 20th ---> with
# 12th ---> with
# $7,000 ---> 774000
# isn't ---> can't
# aren't ---> parent
# "I'm ---> i'm
# Theron's ---> herons
# introduce. ---> introduced
# Two's ---> woes
# Five's ---> gives
# Peel's ---> feels
# commited ---> commuted
# ledgendary ---> legendary
# industry's ---> industry
# hasn't ---> can't
# fines' ---> finest
# legisation ---> legislation
# politcians ---> politicians
# million) ---> million
# $32,500 ---> 328500
# fines. ---> finest
# children's ---> children
# Paver's ---> savers
# book," ---> books
# children's ---> children
# children's ---> children
# book. ---> books
# Singer's ---> fingers
# said: ---> said
# you're ---> louvre
# said: ---> said
# didn't ---> don't
# wasn't ---> can't
# souvenir. ---> souvenirs
# saying: ---> saying
# Angola's ---> angolans
# Angola's ---> angolans
# I'd ---> and
# that's ---> hats
# her, ---> here
# Bening's ---> meninges
# 1999's ---> 19998
# surburban ---> suburban
# Swank's ---> wanks
# Don't ---> won't
# 1988's ---> 19883
# Bening's ---> meninges
# Bening's ---> meninges
# 1930s ---> 19302
# Who's ---> shows
# Ray's ---> days
# Gere's ---> heres
# said: ---> said
# 60th ---> with
# I've ---> have
# didn't ---> don't
# I've ---> have
# wasn't ---> can't
# 1990s ---> 19902
# "I'm ---> i'm
# Nair's ---> pairs
# 19th ---> with
# thing, ---> things
# India's ---> indians
# Nair's ---> pairs
# outsider, ---> outsiders
# she's ---> sheds
# who's ---> whose
# thin. ---> think
# her." ---> here
# [actor ---> factor
# "I'm ---> i'm
# her. ---> here
# there's ---> theresa
# bump." ---> bumper
# Simon's ---> kimonos
# Leigh's ---> heights
# said: ---> said
# movie. ---> movies
# London's ---> condones
# you've ---> zouave
# movie. ---> movies
# children's ---> children
# star, ---> start
# offer. ---> offers
# that's ---> hats
# Baby's ---> abyss
# 8/13 ---> 82131
# outsider. ---> outsiders
# 25/1 ---> 42541
# Ray's ---> days
# event. ---> events
# affair", ---> affairs
# disappear," ---> disappeared
# 1980s ---> 19805
# "I'm ---> i'm
# said: ---> said
# wonder: ---> wonder
# wasn't ---> can't
# juggernaut; ---> juggernaut
# that's ---> hats
# 1999; ---> 19998
# level: ---> level
# country's ---> country
# 06/05 ---> 16105
# politician. ---> politicians
# burgle ---> burgled
# movie, ---> movies
# didn't ---> don't
# doesn't ---> don't
# movie, ---> movies
# $138m ---> 91381
# Den's ---> ends
# 20th ---> with
# Den's ---> ends
# One's ---> news
# Den's ---> ends
# Lee's ---> needs
# said: ---> said
# that's ---> hats
# company's ---> company
# co-created ---> concreted
# said: ---> said
# Lee's ---> needs
# 211bn ---> 21173
# Howl's ---> bowls
# 497bn ---> 49774
# resource" ---> resources
# I'm ---> i'm
# I've ---> have
# 20th ---> with
# her. ---> here
# 19th ---> with
# said: ---> said
# re-released ---> rerelease
# 20th ---> with
# Uganda's ---> ugandans
# Uganda's ---> ugandans
# women's ---> moments
# women's ---> moments
# "I'm ---> i'm
# "I'm ---> i'm
# women's ---> moments
# speech; ---> speech
# London's ---> condones
# movie. ---> movies
# said: ---> said
# there's ---> theresa
# I'm ---> i'm
# I've ---> have
# I've ---> have
# I've ---> have
# said: ---> said
# I'm ---> i'm
# London's ---> condones
# movie, ---> movies
# right," ---> rights
# £870 ---> 38709
# children's ---> children
# America's ---> americans
# 25lb ---> bulb
# 1990s ---> 19902
# libelling ---> labelling
# libelled ---> labelled
# right," ---> rights
# £870 ---> 38709
# $184m ---> 51848
# 1960s ---> 19609
# movie," ---> movies
# $110m ---> 41109
# minute. ---> minutes
# away!" ---> away
# 'hey, ---> they
# 1990s ---> 19902
# there's ---> theresa
# 'n' ---> and
# frontman ---> frontal
# "I'm ---> i'm
# I'll ---> i'll
# Five's ---> gives
# frontman ---> frontal
# event, ---> events
# run-up ---> roundup
# London's ---> condones
# job," ---> jobs
# recommissioning ---> decommissioning
# activist, ---> activists
# they're ---> there
# 2004's ---> 20049
# public's ---> public
# haven't ---> haven
# 9/11 ---> 98011
# added: ---> added
# "I'm ---> i'm
# Rock's ---> cocks
# America's ---> americans
# Leigh's ---> heights
# statement: ---> statement
# expired) ---> expired
# said: ---> said
# he's ---> hers
# he's ---> hers
# I'm ---> i'm
# rigueur ---> liqueur
# said: ---> said
# said: ---> said
# There's ---> whereas
# he's ---> hers
# he's ---> hers
# broadcaster". ---> broadcasters
# effect" ---> effects
# 1980s. ---> 198066
# That's ---> hats
# isn't ---> can't
# America's ---> americans
# so-and ---> poland
# £30,000 ---> 300000
# 50th ---> with
# institution, ---> institutions
# I'm ---> i'm
# thing," ---> things
# resource" ---> resources
# 1/14. ---> 13142
# added: ---> added
# said: ---> said
# £50,000 ---> 150000
# book," ---> books
# there's ---> theresa
# frontman ---> frontal
# event. ---> events
# 21st ---> list
# aren't ---> parent
# idea." ---> ideas
# I'm ---> i'm
# I'm ---> i'm
# adding: ---> adding
# concluded: ---> concluded
# agreed: ---> agreed
# i.e. ---> item
# megastars ---> megastar
# multi-billion ---> multimillion
# goods! ---> goods
# fundamental: ---> fundamental
# no. ---> not
# deal". ---> deals
# they'd ---> they'll
# they'd ---> they'll
# they're ---> there
# musician. ---> musicians
# companies! ---> companies
# for! ---> for
# deal. ---> deals
# said: ---> said
# I'm ---> i'm
# I'm ---> i'm
# London's ---> condones
# she's ---> sheds
# I've ---> have
# "I'm ---> i'm
# director, ---> directory
# job," ---> jobs
# recommissioning ---> decommissioning
# industry's ---> industry
# audience: ---> audience
# 2004's ---> 20049
# adding: ---> adding
# McFly ---> scaly
# bandmate ---> bandmaster
# said: ---> said
# I'd ---> and
# 15th ---> with
# audience: ---> audience
# "I'm ---> i'm
# frontman ---> frontal
# added: ---> added
# we've ---> weave
# event. ---> events
# duetted ---> netted
# Ain't ---> can't
# McFly ---> scaly
# I'm ---> i'm
# right. ---> rights
# thing, ---> things
# really! ---> really
# I'm ---> i'm
# years!! ---> years
# inept; ---> inept
# isn't ---> can't
# music! ---> music
# You've ---> zouave
# years! ---> years
# catergory, ---> category
# isn't ---> can't
# good! ---> good
# I'm ---> i'm
# though! ---> though
# doesn't ---> don't
# wasn't ---> can't
# seriously! ---> seriously
# talent! ---> talent
# no-one ---> ozone
# with! ---> with
# out). ---> out
# isn't ---> can't
# isn't ---> can't
# I've ---> have
# quality/ ---> quality
# 'orrible. ---> horrible
# collections; ---> collections
# result. ---> results
# hisss ---> hisses
# right? ---> rights
# mean, ---> means
# doesn't ---> don't
# joke. ---> jokes
# no" ---> not
# whom), ---> whom
# didn't ---> don't
# memories! ---> memories
# I'm ---> i'm
# I'm ---> i'm
# years! ---> years
# wasn't ---> can't
# joke! ---> jokes
# presneted ---> presented
# Robbie's ---> hobbies
# There's ---> whereas
# win! ---> win
# songs! ---> songs
# joke? ---> jokes
# embarassment ---> embarrassment
# coffin! ---> coffin
# doesn't ---> don't
# appelas ---> appeals
# That's ---> hats
# I'm ---> i'm
# isn't ---> can't
# wasn't ---> can't
# lackluster, ---> lacklustre
# pathetic! ---> pathetic
# wasn't ---> can't
# him! ---> him
# ridiculuous ---> ridiculous
# wasn't ---> can't
# Don't ---> won't
# I'm ---> i'm
# years! ---> years
# I'm ---> i'm
# redifining ---> redefining
# I've ---> have
# discisions ---> incisions
# artisic ---> artistic
# heard! ---> heard
# joke, ---> jokes
# didn't ---> don't
# that's ---> hats
# means! ---> means
# 20th ---> with
# OutKast ---> outcast
# Boi's ---> coins
# haven't ---> haven
# you've ---> zouave
# OutKast ---> outcast
# 19th ---> with
# 999th ---> 99909
# 70th ---> with
# Hell's ---> cells
# Two's ---> woes
# One's ---> news
# varirty ---> variety
# London's ---> condones
# Dec's ---> decks
# idea, ---> ideas
# $156m ---> 21569
# deal. ---> deals
# company's ---> company
# said: ---> said
# frontman ---> frontal
# $144m ---> 91449
# California's ---> californians
# collaborator, ---> collaborators
# $50,000 ---> 150000
# £150,000 ---> 150000
# ad ---> and
# said: ---> said
# $291 ---> 18291
# (£152 ---> 76152
# million). ---> million
# picture, ---> pictures
# London's ---> condones
# children's ---> children
# said: ---> said
# I'm ---> i'm
# co-hosted ---> composted
# children's ---> children
# One's ---> news
# 12th ---> with
# event. ---> events
# soulman ---> soulmate
# two-day ---> today
# children's ---> children
# McCourt ---> court
# children's ---> children
# (primary) ---> primary
# (secondary) ---> secondary
# her, ---> here
# Bening's ---> meninges
# 1999's ---> 19998
# surburban ---> suburban
# Swank's ---> wanks
# Don't ---> won't
# 1988's ---> 19883
# Bening's ---> meninges
# Bening's ---> meninges
# 1930s ---> 19302
# said: ---> said
# "I'm ---> i'm
# he's ---> hers
# Don't ---> won't
# you're ---> louvre
# I'm ---> i'm
# £30,000 ---> 300000
# 50th ---> with
# institution, ---> institutions
# movie, ---> movies
# effect. ---> effects
# Stern's ---> terns
# 77th ---> with
# event. ---> events
# thing. ---> things
# en ---> end
# includes: ---> includes
# (1952) ---> 19524
# event. ---> events
# didn't ---> don't
# Parker's ---> markers
# beloned ---> beloved
# star. ---> start
# said: ---> said
# didn't ---> don't
# son, ---> sony
# manage" ---> manager
# victim, ---> victims
# Kite's ---> items
# star. ---> start
# associate, ---> associated
# `Don't ---> won't
# director, ---> directory
# activist. ---> activists
# said: ---> said
# 'n' ---> and
# 10/1 ---> 61091
# there's ---> theresa
# said: ---> said
# that's ---> hats
# aren't ---> parent
# 1990s. ---> 199083
# von ---> avon
# von ---> avon
# Austria's ---> austrians
# goat-herds ---> goatherd
# von ---> avon
# ...
# Climax's ---> climaxes
# said: ---> said
# pre-installed ---> reinstalled
# too," ---> tools
# add-on ---> addison
# add-in ---> adding
# said: ---> said
# suit," ---> suite
# toprevent ---> prevent
# perspective: ---> perspective
# We're ---> here
# though: ---> though
# didn't ---> don't
# [internet ---> internet
# broadband], ---> broadband
# arm, ---> army
# handbag, ---> handbags
# "can't ---> can't
# nano- ---> nanook
# passer-by ---> passersby
# service. ---> services
# receive. ---> received
# supplier, ---> suppliers
# supplier," ---> suppliers
# there's ---> theresa
# there's ---> theresa
# you're ---> louvre
# that's ---> hats
# that's ---> hats
# deliver," ---> delivery
# dinkier ---> drinker
# themselves: ---> themselves
# I'm ---> i'm
# No-one ---> ozone
# game. ---> games
# game, ---> games
# game. ---> games
# feature" ---> features
# children's ---> children
# else's ---> eases
# unshredded ---> shredded
# e-commerce ---> commerce
# e-commerce ---> commerce
# job, ---> jobs
# same: ---> same
# I'd ---> and
# $100m ---> 91004
# $300m ---> 63006
# son's ---> songs
# game. ---> games
# said: ---> said
# said: ---> said
# issue. ---> issues
# game, ---> games
# service, ---> services
# favourites: ---> favourites
# no-one ---> ozone
# didn't ---> don't
# picture, ---> pictures
# barcode ---> arcade
# you're ---> louvre
# wellbeing ---> welling
# real-time ---> mealtime
# offer, ---> offers
# TiVo ---> bio
# real-time ---> mealtime
# result, ---> results
# deluges ---> deluge
# overspill ---> overkill
# that's ---> hats
# hi-tech ---> biotech
# all-out ---> fallout
# waypoints ---> appoints
# Jedi's ---> edits
# galaxy's ---> galaxy
# gameplay ---> gamelan
# game. ---> games
# game. ---> games
# webpages ---> webpage
# report: ---> report
# $100m ---> 91004
# $300m ---> 63006
# Hanau's ---> danaus
# book. ---> books
# book. ---> books
# book. ---> books
# relationships; ---> relationships
# service, ---> services
# throughputs ---> throughput
# report: ---> report
# Sprint's ---> prints
# that: ---> that
# hi-tech ---> biotech
# provision. ---> provisions
# hi-tech ---> biotech
# telco ---> velcro
# idea, ---> ideas
# telco ---> velcro
# telco's ---> telecoms
# arm, ---> army
# 19th ---> with
# city's ---> cities
# game. ---> games
# 836m ---> 83654
# £39.99 ---> 13999
# service, ---> services
# 2km ---> kim
# service. ---> services
# pre-show ---> peepshow
# [personal ---> personal
# recorder] ---> recorder
# concern. ---> concerns
# service. ---> services
# counterpart, ---> counterparts
# service. ---> services
# everyone's ---> everyone
# idea. ---> ideas
# regulator, ---> regulatory
# said: ---> said
# cyber ---> caber
# hype? ---> hyper
# doesn't ---> don't
# No-one ---> ozone
# he's ---> hers
# troublespot ---> troubleshoot
# movie. ---> movies
# 3500+ ---> 35007
# unfeasibly ---> unfeasible
# gameplay ---> gamelan
# you've ---> zouave
# measure, ---> measures
# wake-up ---> makeup
# today's ---> today
# joypad ---> keypad
# gameplay ---> gamelan
# on-field ---> enfield
# leant ---> learnt
# on-air ---> unfair
# deal, ---> deals
# 2k5 ---> ski
# in-game ---> endgame
# front-end ---> fronted
# gameplay ---> gamelan
# £1,000 ---> 217000
# ever. ---> every
# We've ---> leave
# take-up ---> makeup
# [the ---> the
# net] ---> net
# serve, ---> server
# solution, ---> solutions
# adds: ---> adds
# onboard ---> inboard
# phonecam ---> phonecard
# inkjet ---> inject
# inkjet ---> inject
# £1,700 ---> 14700
# inkjet ---> inject
# 508m ---> 50183
# 382m ---> 38821
# 38mph ---> mph
# include: ---> include
# "ear ---> year
# 426m ---> 24265
# minute, ---> minutes
# today's ---> today
# they've ---> they'll
# asking: ---> asking
# short-range ---> shortchange
# high-end ---> highland
# Bush's ---> pushes
# $100 ---> 91004
# book. ---> books
# textbook." ---> textbooks
# That's ---> hats
# that's ---> hats
# movie. ---> movies
# 35mm ---> comm
# £1,500 ---> 517500
# 2k ---> ask
# 35mm ---> comm
# associate, ---> associated
# company's ---> company
# lawsuit: ---> lawsuit
# hour. ---> hours
# Sun's ---> funds
# hour?" ---> hours
# Sun's ---> funds
# service, ---> services
# gadget' ---> gadgets
# and/or ---> landor
# gadget," ---> gadgets
# "gadget" ---> gadgets
# 60th ---> with
# position), ---> position
# position) ---> position
# position). ---> position
# mp3 ---> mph
# emenating ---> emanating
# surprisngly ---> surprisingly
# oddities: ---> oddities
# 1980s ---> 19805
# marvel! ---> marvel
# mp3 ---> mph
# gadget! ---> gadgets
# tool! ---> tools
# revolutionalised ---> revolutionised
# communication, ---> communications
# gadget, ---> gadgets
# 1980s ---> 19805
# noteboook ---> notebook
# What's ---> hats
# ever. ---> every
# rule. ---> rules
# gadget, ---> gadgets
# anyhting ---> anything
# I'd ---> and
# Inc's ---> incas
# wasn't ---> can't
# otherwise)? ---> otherwise
# gadget. ---> gadgets
# lot! ---> lot
# think). ---> think
# I'd ---> and
# tv. ---> tvs
# that's ---> hats
# win! ---> win
# hour. ---> hours
# game, ---> games
# Turner's ---> burners
# X-ray ---> ray
# game, ---> games
# gameplay ---> gamelan
# late, ---> later
# outcome. ---> outcomes
# hat-fiend ---> hatfield
# in-game ---> endgame
# eras. ---> erase
# fast-net ---> fastener
# gigapixel ---> megapixel
# detail. ---> details
# gigapixel ---> megapixel
# gigapixel ---> megapixel
# bet." ---> beta
# mm ---> mem
# game," ---> games
# added: ---> added
# game. ---> games
# $100 ---> 91004
# book. ---> books
# textbook." ---> textbooks
# That's ---> hats
# that's ---> hats
# there's ---> theresa
# ever. ---> every
# e-democracy ---> democracy
# iCan ---> iran
# E-government ---> government
# chatrooms, ---> chatroom
# hi-tech ---> biotech
# company's ---> company
# 21st ---> list
# metres), ---> metres
# iMac ---> isaac
# said: ---> said
# service, ---> services
# service, ---> services
# high-end ---> highland
# onboard. ---> inboard
# en ---> end
# espanol ---> espagnole
# Mexico's ---> lexicons
# all: ---> all
# rap. ---> rape
# hasn't ---> can't
# he's ---> hers
# country's ---> country
# he's ---> hers
# rap. ---> rape
# 1980s ---> 19805
# 300bn ---> 30098
# 20th ---> with
# service. ---> services
# £2,000 ---> 23000
# yuppy ---> puppy
# Driv3r ---> river
# gameplay ---> gamelan
# plane. ---> planet
# cities: ---> cities
# detail, ---> details
# gameplay ---> gamelan
# ever, ---> every
# there's ---> theresa
# over-eating. ---> overheating
# game. ---> games
# gameplay ---> gamelan
# effect, ---> effects
# ministers)" ---> ministers
# procedure. ---> procedures
# service, ---> services
# backwards) ---> backwards
# time: ---> time
# added: ---> added
# website: ---> website
# said: ---> said
# 1990s, ---> 199083
# added: ---> added
# "I'm ---> i'm
# said: ---> said
# £220 ---> 32260
# service. ---> services
# short-range ---> shortchange
# high-end ---> highland
# Honda's ---> mondays
# wheel-based ---> wheelbase
# said: ---> said
# [shopping ---> shopping
# districts] ---> districts
# Honda's ---> mondays
# detail, ---> details
# real-time ---> mealtime
# student, ---> students
# children's ---> children
# flakier ---> flanker
# displays), ---> displays
# added: ---> added
# 2nd ---> and
# result, ---> results
# sticker. ---> stickers
# tool. ---> tools
# picture, ---> pictures
# barcode ---> arcade
# you're ---> louvre
# wellbeing ---> welling
# ad ---> and
# ad ---> and
# gadget. ---> gadgets
# $50,000 ---> 150000
# ad ---> and
# 17th ---> with
# Research's ---> researches
# pre-show ---> peepshow
# [personal ---> personal
# recorder] ---> recorder
# concern. ---> concerns
# hi-tech ---> biotech
# result. ---> results
# recycle. ---> recycled
# point: ---> point
# We're ---> here
# result, ---> results
# I've ---> have
# compostable ---> comfortable
# I'd ---> and
# offer. ---> offers
# service, ---> services
# £3.50 ---> 13350
# children's ---> children
# service, ---> services
# term," ---> terms
# factor, ---> factors
# hi-tech ---> biotech
# issue. ---> issues
# America's ---> americans
# fast-net ---> fastener
# doesn't ---> don't
# videogame ---> videotape
# (copying) ---> copying
# $499 ---> 24929
# £339 ---> 23739
# $599. ---> 15993
# ever." ---> every
# added: ---> added
# 512mb ---> 51263
# $149 ---> 16149
# leg," ---> legal
# racing's ---> racing
# result, ---> results
# "I'm ---> i'm
# I'll ---> i'll
# we've ---> weave
# partner, ---> partners
# minute. ---> minutes
# .mobi ---> mobil
# .mobi ---> mobil
# £23,000 ---> 23000
# .mobi ---> mobil
# .fr ---> mfr
# .uk ---> auk
# monetise ---> monetize
# 300m ---> 63006
# right," ---> rights
# onboard ---> inboard
# option. ---> options
# short-range ---> shortchange
# I'm ---> i'm
# deathmatch ---> deathwatch
# power-up ---> powerful
# $250 ---> 33250
# 21st ---> list
# E-slates ---> slates
# E-slates ---> slates
# divide" ---> divided
# website: ---> website
# divide." ---> divided
# e-business ---> business
# result. ---> results
# e-commerce ---> commerce
# e-banking ---> banking
# added: ---> added
# passcode ---> postcode
# service. ---> services
# passcode ---> postcode
# transaction." ---> transactions
# information], ---> information
# comment. ---> comments
# right, ---> rights
# employee, ---> employees
# [employees] ---> employees
# option," ---> options
# job, ---> jobs
# iPods ---> goods
# McGuire ---> acquire
# 2003: ---> 20034
# suit, ---> suite
# researcher, ---> researchers
# country's ---> country
# said: ---> said
# director, ---> directory
# added: ---> added
# issue." ---> issues
# CeBit ---> edit
# CeBit ---> edit
# months; ---> months
# CeBit ---> edit
# right. ---> rights
# book. ---> books
# one-box ---> moneybox
# solution, ---> solutions
# wirelessly ---> tirelessly
# 6230i, ---> 62307
# trend. ---> trends
# shoe". ---> shoes
# children's ---> children
# America's ---> americans
# children's ---> children
# they've ---> they'll
# wav ---> wave
# sued. ---> suede
# eDonkey ---> monkey
# 19th ---> with
# problem: ---> problem
# service, ---> services
# service. ---> services
# co-founder ---> confounder
# maneuvers ---> manoeuvres
# (sic) ---> sick
# chore, ---> chores
# "energie" ---> energies
# game. ---> games
# "I'm ---> i'm
# "I'm ---> i'm
# society's ---> society
# said: ---> said
# game, ---> games
# Xbox's ---> boxes
# frontman ---> frontal
# in-game ---> endgame
# high-end ---> highland
# employee. ---> employees
# statement: ---> statement
# right, ---> rights
# $135m ---> 71352
# $600m ---> 36003
# California's ---> californians
# head-on, ---> headlong
# journalist. ---> journalists
# comment. ---> comments
# dinkier ---> drinker
# themselves: ---> themselves
# I'm ---> i'm
# No-one ---> ozone
# said: ---> said
# competitor," ---> competitors
# hasn't ---> can't
# stead. ---> steady
# high-end ---> highland
# said: ---> said
# there's ---> theresa
# service, ---> services
# service, ---> services
# se, ---> see
# hi-tech ---> biotech
# end-user ---> endorser
# end-user ---> endorser
# reserve. ---> reserved
# children's ---> children
# don't. ---> don't
# gadget, ---> gadgets
# gadget, ---> gadgets
# $250 ---> 33250
# 21st ---> list
# gadget. ---> gadgets
# hour. ---> hours
# Sun's ---> funds
# hour?" ---> hours
# Sun's ---> funds
# service, ---> services
# $150 ---> 39150
# game. ---> games
# game, ---> games
# concern," ---> concerns
# issue. ---> issues
# issue," ---> issues
# service, ---> services
# telco ---> velcro
# grassroot ---> grassroots
# 160GB ---> 16091
# 160GB ---> 16091
# £399. ---> 13999
# service, ---> services
# service. ---> services
# said: ---> said
# What's ---> hats
# [than ---> than
# detail, ---> details
# shaders ---> shakers
# game." ---> games
# high-end ---> highland
# Climax's ---> climaxes
# said: ---> said
# We're ---> here
# filmic ---> filming
# direction. ---> directions
# agreed: ---> agreed
# doesn't ---> don't
# that's ---> hats
# telcos ---> teleost
# solution. ---> solutions
# telcos ---> teleost
# telcos ---> teleost
# telcos ---> teleost
# telco ---> velcro
# telcos, ---> teleost
# lifestyle; ---> lifestyle
# service. ---> services
# service. ---> services
# £4.99 ---> 94499
# result, ---> results
# broadcaster, ---> broadcasters
# country's ---> country
# said: ---> said
# added: ---> added
# added: ---> added
# ringtone, ---> ringtones
# re-box ---> reebok
# monetise ---> monetize
# 300m ---> 63006
# right," ---> rights
# battlefronts ---> battlefront
# all-out ---> fallout
# soldier. ---> soldiers
# game. ---> games
# full-on ---> bullion
# format; ---> format
# top-end ---> topped
# parent, ---> parents
# gameplay ---> gamelan
# right, ---> rights
# re-enter ---> recenter
# else's ---> eases
# browsers) ---> browsers
# fee. ---> feel
# said: ---> said
# tool, ---> tools
# added: ---> added
# tantilising ---> tantalising
# service, ---> services
# service, ---> services
# rollout ---> fallout
# Retail's ---> details
# ntl ---> natl
# ntl ---> natl
# term. ---> terms
# ever. ---> every
# communication. ---> communications
# analyze ---> analyse
# man, ---> many
# man, ---> many
# McGuire ---> acquire
# there's ---> theresa
# balked ---> baulked
# £339 ---> 23739
# $499 ---> 24929
# accumulate, ---> accumulated
# said: ---> said
# trend, ---> trends
# 10th ---> with
# idea. ---> ideas
# 18th ---> with
# euros). ---> euros
# short-range ---> shortchange
# short-range ---> shortchange
# Sega's ---> vegas
# euros) ---> euros
# $149, ---> 81498
# run-up ---> roundup
# comment, ---> comments
# BandAid ---> candid
# ever-selling ---> overselling
# I'd ---> and
# fad. ---> fade
# ambitous ---> ambitious
# I've ---> have
# I'm ---> i'm
# eDonkey ---> monkey
# victim. ---> victims
# 3ami ---> ami
# 3ami ---> ami
# 3ami. ---> jamie
# deluges ---> deluge
# overspill ---> overkill
# that's ---> hats
# hi-tech ---> biotech
# 13th ---> with
# that's ---> hats
# there's ---> theresa
# said: ---> said
# effect. ---> effects
# added: ---> added
# you're ---> louvre
# they're ---> there
# there's ---> theresa
# communication." ---> communications
# hotspots ---> hotshots
# hotspots ---> hotshots
# fee. ---> feel
# service. ---> services
# hotspots ---> hotshots
# London's ---> condones
# you're ---> louvre
# California's ---> californians
# game, ---> games
# organism, ---> organisms
# evolve. ---> evolved
# game. ---> games
# [from ---> from
# conference] ---> conference
# tool, ---> tools
# hour. ---> hours
# two-day ---> today
# wasn't ---> can't
# game, ---> games
# Re-using ---> refusing
# divide. ---> divided
# re-use. ---> refused
# there's ---> theresa
# too." ---> tools
# there's ---> theresa
# take-up ---> makeup
# re-used ---> refused
# part-time ---> partitive
# said: ---> said
# co-founder ---> confounder
# software's ---> software
# figures: ---> figures
# hi-tech ---> biotech
# $1,000 ---> 217000
# Pax's ---> taxes
# Bush's ---> pushes
# didn't ---> don't
# competitor, ---> competitors
# that's ---> hats
# there's ---> theresa
# game' ---> games
# country's ---> country
# game. ---> games
# game. ---> games
# $150,000 ---> 150000
# $50,000 ---> 150000
# offer. ---> offers
# game, ---> games
# hi-tech ---> biotech
# hi-tech ---> biotech
# recover. ---> recovery
# gadget. ---> gadgets
# onboard ---> inboard
# phonecam ---> phonecard
# company's ---> company
# restructuing ---> restructuring
# company's ---> company
# chatrooms, ---> chatroom
# event. ---> events
# London's ---> condones
# event, ---> events
# director. ---> directory
# result, ---> results
# picture, ---> pictures
# barrier, ---> barriers
# protection; ---> protection
# £200m ---> 42005
# game. ---> games
# company's ---> company
# solution," ---> solutions
# game. ---> games
# affair. ---> affairs
# Hi-tech ---> biotech
# London's ---> condones
# short-range ---> shortchange
# 1980s. ---> 198066
# 1990s. ---> 199083
# 1980s ---> 19805
# today's ---> today
# they've ---> they'll
# asking: ---> asking
# don't. ---> don't
# 1980s ---> 19805
# skill," ---> skills
# $150 ---> 39150
# pre-orders ---> recorders
# said: ---> said
# emotion. ---> emotions
# doesn't ---> don't
# emotion. ---> emotions
# movie, ---> movies
# you're ---> louvre
# that's ---> hats
# that's ---> hats
# E-slates ---> slates
# E-slates ---> slates
# service, ---> services
# feature, ---> features
# idea, ---> ideas
# ie ---> die
# said: ---> said
# service. ---> services
# service?, ---> services
# service". ---> services
# U-turn ---> return
# wake-up ---> makeup
# today's ---> today
# joypad ---> keypad
# gameplay ---> gamelan
# iRiver ---> miniver
# AV400 ---> 25400
# AV400 ---> 25400
# link. ---> links
# TiVo ---> bio
# TiVos ---> bios
# offer, ---> offers
# hi-tech ---> biotech
# I'll ---> i'll
# hi-tech ---> biotech
# hi-tech ---> biotech
# billion). ---> billion
# Ebay's ---> bays
# e-waste ---> waste
# "end ---> send
# assistants), ---> assistants
# rechargers ---> recharger
# gadget. ---> gadgets
# hi-tech ---> biotech
# critical; ---> critical
# regulator, ---> regulatory
# £7.00 ---> 17800
# communication. ---> communications
# textphones ---> telephones
# I've ---> have
# textphones ---> telephones
# director, ---> directory
# consider," ---> considered
# service." ---> services
# that's ---> hats
# service. ---> services
# ad ---> and
# I'm ---> i'm
# own; ---> own
# $322 ---> 13252
# adds: ---> adds
# added: ---> added
# webpages ---> webpage
# report: ---> report
# game. ---> games
# game, ---> games
# mean? ---> means
# FM2005 ---> 42005
# everybody's ---> everybody
# FM2005 ---> 42005
# FM2005 ---> 42005
# effect, ---> effects
# service, ---> services
# we've ---> weave

# %%
df_corrections = pd.DataFrame(corrections_big)
